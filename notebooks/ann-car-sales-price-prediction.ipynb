# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler

from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('car_purchasing.csv', encoding='ISO-8859-1')

# Check the first few rows of the dataset
print(df.head())
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
X = df.drop('car purchase amount', axis=1)
y = df['car purchase amount']

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 4)
# (400, 1)
# (100, 4)
# (100, 1)

# %%
model = Sequential()
model.add(Dense(10, activation='relu', input_dim=4))
model.add(Dense(10, activation='relu'))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mean_squared_error', metrics=['mean_absolute_error'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 10)                50
#
#  dense_1 (Dense)             (None, 10)                110
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 171 (684.00 Byte)
# Trainable params: 171 (684.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = model.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 26ms/step - loss: 0.9592 - mean_absolute_error: 0.7609 - val_loss: 1.1653 - val_mean_absolute_error: 0.8883
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.8709 - mean_absolute_error: 0.7245 - val_loss: 1.0696 - val_mean_absolute_error: 0.8466
# Epoch 3/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.7901 - mean_absolute_error: 0.6886 - val_loss: 0.9857 - val_mean_absolute_error: 0.8084
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.7212 - mean_absolute_error: 0.6578 - val_loss: 0.9125 - val_mean_absolute_error: 0.7731
# Epoch 5/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.6605 - mean_absolute_error: 0.6272 - val_loss: 0.8407 - val_mean_absolute_error: 0.7383
# Epoch 6/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.6000 - mean_absolute_error: 0.5958 - val_loss: 0.7737 - val_mean_absolute_error: 0.7033
# Epoch 7/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.5420 - mean_absolute_error: 0.5649 - val_loss: 0.7098 - val_mean_absolute_error: 0.6692
# Epoch 8/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.4907 - mean_absolute_error: 0.5346 - val_loss: 0.6449 - val_mean_absolute_error: 0.6330
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.4376 - mean_absolute_error: 0.5015 - val_loss: 0.5853 - val_mean_absolute_error: 0.5962
# Epoch 10/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3883 - mean_absolute_error: 0.4683 - val_loss: 0.5256 - val_mean_absolute_error: 0.5574
# Epoch 11/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.3407 - mean_absolute_error: 0.4337 - val_loss: 0.4684 - val_mean_absolute_error: 0.5189
# Epoch 12/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2983 - mean_absolute_error: 0.4002 - val_loss: 0.4126 - val_mean_absolute_error: 0.4782
# Epoch 13/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2596 - mean_absolute_error: 0.3680 - val_loss: 0.3604 - val_mean_absolute_error: 0.4368
# Epoch 14/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.2213 - mean_absolute_error: 0.3336 - val_loss: 0.3163 - val_mean_absolute_error: 0.3991
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.1890 - mean_absolute_error: 0.3026 - val_loss: 0.2766 - val_mean_absolute_error: 0.3636
# Epoch 16/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1605 - mean_absolute_error: 0.2739 - val_loss: 0.2400 - val_mean_absolute_error: 0.3313
# Epoch 17/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1366 - mean_absolute_error: 0.2495 - val_loss: 0.2100 - val_mean_absolute_error: 0.3082
# Epoch 18/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1164 - mean_absolute_error: 0.2308 - val_loss: 0.1856 - val_mean_absolute_error: 0.2918
# Epoch 19/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1007 - mean_absolute_error: 0.2178 - val_loss: 0.1649 - val_mean_absolute_error: 0.2778
# Epoch 20/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0879 - mean_absolute_error: 0.2078 - val_loss: 0.1485 - val_mean_absolute_error: 0.2650
# Epoch 21/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0782 - mean_absolute_error: 0.2000 - val_loss: 0.1347 - val_mean_absolute_error: 0.2526
# Epoch 22/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0712 - mean_absolute_error: 0.1946 - val_loss: 0.1219 - val_mean_absolute_error: 0.2411
# Epoch 23/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0645 - mean_absolute_error: 0.1874 - val_loss: 0.1121 - val_mean_absolute_error: 0.2320
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0594 - mean_absolute_error: 0.1816 - val_loss: 0.1041 - val_mean_absolute_error: 0.2253
# Epoch 25/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0553 - mean_absolute_error: 0.1760 - val_loss: 0.0956 - val_mean_absolute_error: 0.2163
# Epoch 26/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0511 - mean_absolute_error: 0.1699 - val_loss: 0.0895 - val_mean_absolute_error: 0.2102
# Epoch 27/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0477 - mean_absolute_error: 0.1641 - val_loss: 0.0827 - val_mean_absolute_error: 0.2023
# Epoch 28/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0447 - mean_absolute_error: 0.1587 - val_loss: 0.0770 - val_mean_absolute_error: 0.1964
# Epoch 29/50
# 10/10 [==============================] - 0s 11ms/step - loss: 0.0418 - mean_absolute_error: 0.1536 - val_loss: 0.0721 - val_mean_absolute_error: 0.1901
# Epoch 30/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0393 - mean_absolute_error: 0.1485 - val_loss: 0.0674 - val_mean_absolute_error: 0.1851
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0369 - mean_absolute_error: 0.1439 - val_loss: 0.0635 - val_mean_absolute_error: 0.1811
# Epoch 32/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0349 - mean_absolute_error: 0.1402 - val_loss: 0.0594 - val_mean_absolute_error: 0.1748
# Epoch 33/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0329 - mean_absolute_error: 0.1359 - val_loss: 0.0561 - val_mean_absolute_error: 0.1698
# Epoch 34/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0311 - mean_absolute_error: 0.1320 - val_loss: 0.0533 - val_mean_absolute_error: 0.1659
# Epoch 35/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0296 - mean_absolute_error: 0.1287 - val_loss: 0.0501 - val_mean_absolute_error: 0.1605
# Epoch 36/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0281 - mean_absolute_error: 0.1254 - val_loss: 0.0478 - val_mean_absolute_error: 0.1573
# Epoch 37/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0269 - mean_absolute_error: 0.1226 - val_loss: 0.0458 - val_mean_absolute_error: 0.1546
# Epoch 38/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0257 - mean_absolute_error: 0.1193 - val_loss: 0.0436 - val_mean_absolute_error: 0.1505
# Epoch 39/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0245 - mean_absolute_error: 0.1170 - val_loss: 0.0416 - val_mean_absolute_error: 0.1472
# Epoch 40/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0236 - mean_absolute_error: 0.1148 - val_loss: 0.0397 - val_mean_absolute_error: 0.1442
# Epoch 41/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0228 - mean_absolute_error: 0.1134 - val_loss: 0.0381 - val_mean_absolute_error: 0.1415
# Epoch 42/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0218 - mean_absolute_error: 0.1103 - val_loss: 0.0367 - val_mean_absolute_error: 0.1392
# Epoch 43/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0211 - mean_absolute_error: 0.1086 - val_loss: 0.0354 - val_mean_absolute_error: 0.1378
# Epoch 44/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0204 - mean_absolute_error: 0.1070 - val_loss: 0.0340 - val_mean_absolute_error: 0.1365
# Epoch 45/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0197 - mean_absolute_error: 0.1052 - val_loss: 0.0328 - val_mean_absolute_error: 0.1348
# Epoch 46/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0192 - mean_absolute_error: 0.1039 - val_loss: 0.0318 - val_mean_absolute_error: 0.1337
# Epoch 47/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0185 - mean_absolute_error: 0.1021 - val_loss: 0.0306 - val_mean_absolute_error: 0.1321
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0180 - mean_absolute_error: 0.1008 - val_loss: 0.0298 - val_mean_absolute_error: 0.1310
# Epoch 49/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0175 - mean_absolute_error: 0.0994 - val_loss: 0.0289 - val_mean_absolute_error: 0.1295
# Epoch 50/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0170 - mean_absolute_error: 0.0980 - val_loss: 0.0279 - val_mean_absolute_error: 0.1279

# %%
y_pred = model.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 1ms/step

# %%
from sklearn.metrics import r2_score

R2 = r2_score(y_test, y_pred)
print("R2 Score=",R2 )
# Out:
# R2 Score= 0.965911409729459
